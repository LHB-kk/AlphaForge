# %%
import os
import numpy as np
from alphagen.data.expression import *
from alphagen.utils import reseed_everything
from alphagen_generic.features import *
from gan.utils.data import get_data_by_year

# %% [markdown]
# # Utility functions

# %%
import pandas as pd
from tqdm import tqdm
def get_ml_data(data):
    df = data.df_bak.copy()
    df.columns = ['open','close','high','low','volume', "vwap"]
    close_unstack = df['close'].unstack()
    tmp = (close_unstack.shift(-20)/close_unstack)-1
    label = tmp.stack().reindex(df.index)
    df['label'] = label

    feature = df[['open','close','high','low','volume',"vwap"]]
    tmp = feature.unstack()
    feature = (tmp/tmp.shift(1)-1)#.stack().reindex(df.index)

    result_feature = []
    cur = feature.stack().reindex(df.index)
    cur.columns = [f'{col}0' for col in cur.columns]
    for past in tqdm(range(1,60)):
        cur = feature.shift(past).stack().reindex(df.index)
        cur.columns = [f'{col}{past}' for col in cur.columns]
        result_feature.append(cur)
    result_feature = pd.concat(result_feature,axis=1)
    df = pd.concat([result_feature,df['label']],axis=1)
    start_date = data._dates[data.max_backtrack_days]
    end_date = data._dates[-data.max_future_days]
    return df.loc[start_date:end_date]

def normalize_data(df_train, df_valid, df_test):
    # Get the column names of the features
    labels = [df_train.iloc[:, -1], df_valid.iloc[:, -1], df_test.iloc[:, -1]]
    df_train_features = df_train.iloc[:, :-1]
    df_valid_features = df_valid.iloc[:, :-1]
    df_test_features = df_test.iloc[:, :-1]

    _mean = df_train_features.mean()
    _std = df_train_features.std()
    print('1')
    df_train_norm = (df_train_features - _mean) / _std
    print('2')
    df_valid_norm = (df_valid_features - _mean) / _std
    print('3')
    df_test_norm = (df_test_features - _mean) / _std

    df_train_norm.fillna(0, inplace=True)
    df_valid_norm.fillna(0, inplace=True)
    df_test_norm.fillna(0, inplace=True)


    df_train_norm['label'] = np.nan_to_num(labels[0],nan=0,posinf=0,neginf=0)
    df_valid_norm['label'] = np.nan_to_num(labels[1],nan=0,posinf=0,neginf=0)
    df_test_norm['label'] = np.nan_to_num(labels[2],nan=0,posinf=0,neginf=0)

    df_train_norm['label'] = df_train_norm['label'].groupby('datetime').transform(lambda x: (x - x.mean()) / x.std()).clip(-4, 4)

    df_train_norm = df_train_norm.clip(-4, 4)
    df_valid_norm = df_valid_norm.clip(-4, 4)
    df_test_norm = df_test_norm.clip(-4, 4)

    return df_train_norm, df_valid_norm, df_test_norm

# %% [markdown]
# # Train Lightgbm Model

# %%
import lightgbm as lgb
import pandas as pd

def train_lightgbm_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label'])
    y_train = df_train_filled['label']
    X_valid = df_valid_filled.drop(columns=['label'])
    y_valid = df_valid_filled['label']
    X_test = df_test_filled.drop(columns=['label'])
    y_test = df_test_filled['label']

    # Convert data to LightGBM Dataset format
    train_data = lgb.Dataset(X_train, label=y_train)
    valid_data = lgb.Dataset(X_valid, label=y_valid)

    # Set hyperparameters for LightGBM model
    params = {
        'objective': 'regression',
        'metric': 'mse',
        'num_leaves': 210,
        'max_depth': 8,
        'learning_rate': 0.05,
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'verbose': 0
    }

    # Train the LightGBM model
    # early_stopping_rounds=100,verbose_eval=100
    model = lgb.train(params, train_data, valid_sets=[train_data, valid_data], num_boost_round=1000, callbacks=[lgb.early_stopping(100), lgb.log_evaluation(100)])

    # Evaluate the model on the test set
    y_pred = model.predict(X_test)
    
    pred = pd.concat([pd.Series(y_pred,index=df_test.index),df_test['label']],axis=1)
    # Print the RMSE score
    # rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    # print(f"RMSE: {rmse}")

    return  model,pred

# for instruments in ['csi300','csi500']:
for instruments in ['csi500']:
    # for train_end in range(2017,2024):
    for train_end in range(2022,2024):
        print(f"instruments: {instruments}\ttrain_end: {train_end}")
        returned = get_data_by_year(
            train_start = 2011,train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',)
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        
        model_name = 'lgbm'
        name = f"{instruments}_{model_name}_{train_end}"
        os.makedirs(f"out_ml/{name}",exist_ok=True)
        model,pred = train_lightgbm_model(df_train, df_valid, df_test)
        model.save_model(f"out_ml/{name}/{model_name}.pt")
        pred.to_pickle(f"out_ml/{name}/pred.pkl")

# %% [markdown]
# # Train Xgboost Model

# %%
import xgboost as xgb
import pandas as pd

def train_xgboost_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label'])
    y_train = df_train_filled['label']
    X_valid = df_valid_filled.drop(columns=['label'])
    y_valid = df_valid_filled['label']
    X_test = df_test_filled.drop(columns=['label'])
    y_test = df_test_filled['label']

    # Convert data to DMatrix format
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_valid, label=y_valid)

    # Set hyperparameters for XGBoost model
    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'colsample_bytree': 0.8879,
        'learning_rate': 0.2,
        'subsample': 0.8789,
        'lambda': 205.6999,
        'alpha': 580.9768,
        'max_depth': 8,
        'num_boost_round': 1000,
        'early_stopping_rounds': 100,
        'verbose_eval': 100
    }

    # Train the XGBoost model
    model = xgb.train(params, dtrain, evals=[(dtrain, 'train'), (dvalid, 'valid')], early_stopping_rounds=params['early_stopping_rounds'], verbose_eval=params['verbose_eval'])

    # Convert test data to DMatrix format
    dtest = xgb.DMatrix(X_test)

    # Make predictions on the test set
    y_pred = model.predict(dtest)

    # Combine the predictions with the actual labels
    # pred = pd.concat([df_test['label'], pd.Series(y_pred, index=df_test.index)], axis=1)
    pred = pd.concat([pd.Series(y_pred,index=df_test.index),df_test['label']],axis=1)

    return model, pred

# for instruments in ['csi300','csi500']:
for instruments in ['csi500']:
    for train_end in range(2022,2023):
        returned = get_data_by_year(
            train_start = 2011,train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',)
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        
        model_name = 'xgb'
        name = f"{instruments}_{model_name}_{train_end}"
        os.makedirs(f"out_ml/{name}",exist_ok=True)
        model,pred = train_xgboost_model(df_train, df_valid, df_test)
        model.save_model(f"out_ml/{name}/{model_name}.pt")
        pred.to_pickle(f"out_ml/{name}/pred.pkl")
# Out:
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:16: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
#   0%|          | 0/59 [00:00<?, ?it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   2%|▏         | 1/59 [00:00<00:22,  2.59it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   3%|▎         | 2/59 [00:00<00:23,  2.40it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:01<00:22,  2.45it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   7%|▋         | 4/59 [00:01<00:22,  2.48it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   8%|▊         | 5/59 [00:02<00:22,  2.41it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:02<00:21,  2.50it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  12%|█▏        | 7/59 [00:02<00:20,  2.48it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  14%|█▎        | 8/59 [00:03<00:20,  2.53it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  15%|█▌        | 9/59 [00:03<00:19,  2.62it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  17%|█▋        | 10/59 [00:03<00:19,  2.58it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  19%|█▊        | 11/59 [00:04<00:18,  2.63it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:04<00:18,  2.55it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  22%|██▏       | 13/59 [00:05<00:17,  2.59it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  24%|██▎       | 14/59 [00:05<00:17,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  25%|██▌       | 15/59 [00:05<00:16,  2.60it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  27%|██▋       | 16/59 [00:06<00:16,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  29%|██▉       | 17/59 [00:06<00:16,  2.60it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:07<00:15,  2.59it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  32%|███▏      | 19/59 [00:07<00:15,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  34%|███▍      | 20/59 [00:07<00:15,  2.56it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  36%|███▌      | 21/59 [00:08<00:14,  2.62it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:08<00:14,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  39%|███▉      | 23/59 [00:08<00:13,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  41%|████      | 24/59 [00:09<00:13,  2.62it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  42%|████▏     | 25/59 [00:09<00:13,  2.61it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  44%|████▍     | 26/59 [00:10<00:12,  2.65it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  46%|████▌     | 27/59 [00:10<00:11,  2.67it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:10<00:11,  2.62it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  49%|████▉     | 29/59 [00:11<00:11,  2.69it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:11<00:10,  2.67it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  53%|█████▎    | 31/59 [00:11<00:10,  2.68it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:12<00:10,  2.66it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  56%|█████▌    | 33/59 [00:12<00:09,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  58%|█████▊    | 34/59 [00:13<00:09,  2.68it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:13<00:09,  2.65it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  61%|██████    | 36/59 [00:13<00:08,  2.63it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  63%|██████▎   | 37/59 [00:14<00:08,  2.63it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  64%|██████▍   | 38/59 [00:14<00:07,  2.66it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  66%|██████▌   | 39/59 [00:14<00:07,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  68%|██████▊   | 40/59 [00:15<00:07,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  69%|██████▉   | 41/59 [00:15<00:06,  2.62it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:16<00:06,  2.66it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  73%|███████▎  | 43/59 [00:16<00:06,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  75%|███████▍  | 44/59 [00:16<00:05,  2.63it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  76%|███████▋  | 45/59 [00:17<00:05,  2.66it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:17<00:04,  2.64it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  80%|███████▉  | 47/59 [00:17<00:04,  2.67it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  81%|████████▏ | 48/59 [00:18<00:04,  2.65it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:18<00:03,  2.67it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:19<00:03,  2.70it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  86%|████████▋ | 51/59 [00:19<00:02,  2.70it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  88%|████████▊ | 52/59 [00:19<00:02,  2.68it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  90%|████████▉ | 53/59 [00:20<00:02,  2.68it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:20<00:01,  2.71it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  93%|█████████▎| 55/59 [00:20<00:01,  2.74it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:21<00:01,  2.74it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  97%|█████████▋| 57/59 [00:21<00:00,  2.73it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:22<00:00,  2.74it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:22<00:00,  2.63it/s]
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:16: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.stack().reindex(df.index)
#   0%|          | 0/59 [00:00<?, ?it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#   5%|▌         | 3/59 [00:00<00:02, 25.39it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  10%|█         | 6/59 [00:00<00:02, 26.04it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  15%|█▌        | 9/59 [00:00<00:01, 27.65it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  20%|██        | 12/59 [00:00<00:01, 26.76it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  25%|██▌       | 15/59 [00:00<00:01, 26.13it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  31%|███       | 18/59 [00:00<00:01, 27.16it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:00<00:01, 25.06it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  42%|████▏     | 25/59 [00:00<00:01, 25.33it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  47%|████▋     | 28/59 [00:01<00:01, 26.10it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  54%|█████▍    | 32/59 [00:01<00:00, 27.48it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  59%|█████▉    | 35/59 [00:01<00:00, 27.30it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  64%|██████▍   | 38/59 [00:01<00:00, 27.55it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:01<00:00, 28.25it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:01<00:00, 29.35it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  83%|████████▎ | 49/59 [00:01<00:00, 29.00it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  88%|████████▊ | 52/59 [00:01<00:00, 27.36it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  95%|█████████▍| 56/59 [00:02<00:00, 29.19it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# ...
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  37%|███▋      | 22/59 [00:00<00:01, 31.53it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  44%|████▍     | 26/59 [00:00<00:01, 31.10it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  51%|█████     | 30/59 [00:00<00:00, 31.58it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  58%|█████▊    | 34/59 [00:01<00:00, 32.80it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  64%|██████▍   | 38/59 [00:01<00:00, 31.00it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  71%|███████   | 42/59 [00:01<00:00, 29.53it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  78%|███████▊  | 46/59 [00:01<00:00, 30.57it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  85%|████████▍ | 50/59 [00:01<00:00, 31.30it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  92%|█████████▏| 54/59 [00:01<00:00, 32.31it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
#  98%|█████████▊| 58/59 [00:01<00:00, 33.36it/s]C:\Users\15416\AppData\Local\Temp\ipykernel_11976\69875456.py:19: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   cur = feature.shift(past).stack().reindex(df.index)
# 100%|██████████| 59/59 [00:01<00:00, 31.24it/s]
# c:\Users\15416\miniconda3\envs\alphagen\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# 1
# 2
# 3
# c:\Users\15416\miniconda3\envs\alphagen\lib\site-packages\xgboost\callback.py:386: UserWarning: [10:41:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "early_stopping_rounds", "num_boost_round", "verbose_eval" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	train-rmse:0.90745	valid-rmse:0.09595
# [9]	train-rmse:0.90635	valid-rmse:0.09708
# C:\Users\15416\AppData\Local\Temp\ipykernel_11976\451480157.py:68: UserWarning: [10:42:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\c_api\c_api.cc:1575: Saving model in the UBJSON format as default.  You can use a file extension: `json` or `ubj` to choose between formats.
#   model.save_model(f"out_ml/{name}/{model_name}.pt")

# %% [markdown]
# # Train MLP Model

# %%
import torch

import torch.nn as nn
import torch.optim as optim
 
def train_mlp_model(df_train, df_valid, df_test):
    # Fill NaN values with 0
    df_train_filled = df_train.fillna(0)
    df_valid_filled = df_valid.fillna(0)
    df_test_filled = df_test.fillna(0)

    # Separate features and labels
    X_train = df_train_filled.drop(columns=['label']).values
    y_train = df_train_filled['label'].values
    X_valid = df_valid_filled.drop(columns=['label']).values
    y_valid = df_valid_filled['label'].values
    X_test = df_test_filled.drop(columns=['label']).values
    y_test = df_test_filled['label'].values

    # Convert data to tensors
    X_train = torch.tensor(X_train, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.float32)
    X_valid = torch.tensor(X_valid, dtype=torch.float32)
    y_valid = torch.tensor(y_valid, dtype=torch.float32)
    X_test = torch.tensor(X_test, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.float32)

    # Define the MLP model
    model = nn.Sequential(
        nn.Linear(X_train.shape[1], 64),
        nn.ReLU(),
        nn.Linear(64, 32),
        nn.ReLU(),
        nn.Linear(32, 1)
    )

    # Define the loss function and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)


    # Move the model to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Train the model
    num_epochs = 10
    batch_size = 512
    for epoch in range(num_epochs):
        # Shuffle the training data
        indices = torch.randperm(X_train.shape[0])
        X_train_shuffled = X_train[indices]
        y_train_shuffled = y_train[indices]

        # Mini-batch training
        for i in tqdm(range(0, X_train.shape[0], batch_size)):
            # Get the mini-batch
            X_batch = X_train_shuffled[i:i+batch_size]
            y_batch = y_train_shuffled[i:i+batch_size]

            # Move the mini-batch to GPU if available
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            # Forward pass
            outputs = model(X_batch)
            loss = criterion(outputs.flatten(), y_batch.flatten())

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Evaluate the model on the test set
    with torch.no_grad():
        # Move the test data to GPU if available
        test_outputs = model(X_test.to(device)).detach().cpu().numpy().flatten()
        pred_df = pd.concat([df_test['label'],pd.Series(test_outputs,index=df_test.index)],axis=1)
    torch.cuda.empty_cache()
    return model, pred_df

# for instruments in ['csi300','csi500']:
for instruments in ['csi500']:
    for train_end in range(2023,2024):
        returned = get_data_by_year(
            train_start = 2011,train_end=train_end,valid_year=train_end+1,test_year =train_end+2,
            instruments=instruments, target=target,freq='day',)
        data_all, data,data_valid,data_valid_withhead,data_test,data_test_withhead,_ = returned
        df_train = get_ml_data(data)
        df_valid = get_ml_data(data_valid)
        df_test = get_ml_data(data_test)
        df_train, df_valid, df_test = normalize_data(df_train, df_valid, df_test)
        for seed in range(4,5):
            reseed_everything(seed)
            model_name = 'mlp'
            name = f"{instruments}_{model_name}_{train_end}"
            os.makedirs(f"out_ml/{name}",exist_ok=True)
            model,pred = train_mlp_model(df_train, df_valid, df_test)
            # model.save_model(f"out_ml/{name}/model.pt")
            pred.to_pickle(f"out_ml/{name}/pred_{seed}.pkl")

# %% [markdown]
# # Show LightGbm Result

# %%
import os
import torch
import numpy as np
from alphagen.utils.correlation import batch_pearsonr, batch_spearmanr,\
      batch_ret, batch_sharpe_ratio, batch_max_drawdown

def chunk_batch_spearmanr(x, y, chunk_size=100):
    n_days = len(x)
    spearmanr_list= []
    for i in range(0, n_days, chunk_size):
        spearmanr_list.append(batch_spearmanr(x[i:i+chunk_size], y[i:i+chunk_size]))
    spearmanr_list = torch.cat(spearmanr_list, dim=0)
    return spearmanr_list

def get_tensor_metrics(x, y, risk_free_rate=0.0):
    # Ensure tensors are 2D (days, stocks)
    if x.dim() > 2: x = x.squeeze(-1)
    if y.dim() > 2: y = y.squeeze(-1)

    ic_s = batch_pearsonr(x, y)
    ric_s = chunk_batch_spearmanr(x, y, chunk_size=400)
    ret_s = batch_ret(x, y) - 0.001

    ic_s = torch.nan_to_num(ic_s, nan=0.)
    ric_s = torch.nan_to_num(ric_s, nan=0.)
    ret_s = torch.nan_to_num(ret_s, nan=0.) / 20
    ic_s_mean = ic_s.mean().item()
    ic_s_std = ic_s.std().item() if ic_s.std().item() > 1e-6 else 1.0
    ric_s_mean = ric_s.mean().item()
    ric_s_std = ric_s.std().item() if ric_s.std().item() > 1e-6 else 1.0
    ret_s_mean = ret_s.mean().item()
    ret_s_std = ret_s.std().item() if ret_s.std().item() > 1e-6 else 1.0
    
    # Calculate Sharpe Ratio and Maximum Drawdown for ret series
    ret_sharpe = batch_sharpe_ratio(ret_s, risk_free_rate).item()
    ret_mdd = batch_max_drawdown(ret_s).item()
    result = dict(
        ic=ic_s_mean,
        ic_std=ic_s_std,
        icir=ic_s_mean / ic_s_std,
        ric=ric_s_mean,
        ric_std=ric_s_std,
        ricir=ric_s_mean / ric_s_std,
        ret=ret_s_mean * len(ret_s) / 3,
        ret_std=ret_s_std,
        retir=ret_s_mean / ret_s_std,
        ret_sharpe=ret_sharpe,
        ret_mdd=ret_mdd,
    )
    return result, ret_s

# %%
import pandas as pd
instruments = 'csi300'

result = []
for year in range(2021,2024):
    result.append(pd.read_pickle(f'out_ml/{instruments}_lgbm_{year}/pred.pkl'))

# def get_final_metrics(df):
#     ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#     ic_s = ic_raw.mean(axis=0)
#     ic_s_std = ic_raw.std(axis=0)
#     icir_s = ic_s/ic_s_std

#     ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#     ric_s = ric_raw.mean(axis=0)
#     ric_s_std = ric_raw.std(axis=0)
#     ricir_s = ric_s/ric_s_std
#     return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}

# print('LightGBM Result:\n')
# print(get_final_metrics(df))
df = pd.concat(result,axis=0)
data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_lgbm_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std      icir       ric   ric_std     ricir       ret  \
# Test  0.008966  0.107411  0.083474  0.013273  0.110982  0.119596 -1.048437
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.246435 -0.018714   -0.297083  1.692358

# %%
import pandas as pd
instruments = 'csi500'

result = []
for year in range(2021,2024):
    result.append(pd.read_pickle(f'out_ml/{instruments}_lgbm_{year}/pred.pkl'))

# def get_final_metrics(df):
#     ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#     ic_s = ic_raw.mean(axis=0)
#     ic_s_std = ic_raw.std(axis=0)
#     icir_s = ic_s/ic_s_std

#     ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#     ric_s = ric_raw.mean(axis=0)
#     ric_s_std = ric_raw.std(axis=0)
#     ricir_s = ric_s/ric_s_std
#     return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}

# print('LightGBM Result:\n')
# print(get_final_metrics(df))
df = pd.concat(result,axis=0)
data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_lgbm_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std      icir       ric   ric_std     ricir       ret  \
# Test  0.017064  0.102383  0.166669  0.032797  0.104813  0.312913  0.514441
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.206998  0.010932    0.173543  1.748943

# %% [markdown]
# # Show XGBoost Result

# %%
import pandas as pd
instruments = 'csi300'

result = []
for year in range(2021,2024):
    result.append(pd.read_pickle(f'out_ml/{instruments}_xgb_{year}/pred.pkl'))
# df = pd.concat(result,0)

# def get_final_metrics(df):
#     ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#     ic_s = ic_raw.mean(axis=0)
#     ic_s_std = ic_raw.std(axis=0)
#     icir_s = ic_s/ic_s_std

#     ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#     ric_s = ric_raw.mean(axis=0)
#     ric_s_std = ric_raw.std(axis=0)
#     ricir_s = ric_s/ric_s_std
#     return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}

# print('XGBoost Result:\n')
# print(get_final_metrics(df))
df = pd.concat(result,axis=0)

data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_xgb_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std      icir       ric   ric_std     ricir       ret  \
# Test  0.035299  0.145951  0.241855  0.054778  0.144985  0.377815  1.435911
#
#        ret_std     retir  ret_sharpe   ret_mdd
# Test  0.044537  0.141823    2.251366  0.489023

# %%
import pandas as pd
instruments = 'csi500'

result = []
for year in range(2021,2024):
    result.append(pd.read_pickle(f'out_ml/{instruments}_xgb_{year}/pred.pkl'))
# df = pd.concat(result,0)

# def get_final_metrics(df):
#     ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#     ic_s = ic_raw.mean(axis=0)
#     ic_s_std = ic_raw.std(axis=0)
#     icir_s = ic_s/ic_s_std

#     ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#     ric_s = ric_raw.mean(axis=0)
#     ric_s_std = ric_raw.std(axis=0)
#     ricir_s = ric_s/ric_s_std
#     return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}

# print('XGBoost Result:\n')
# print(get_final_metrics(df))
df = pd.concat(result,axis=0)

data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
pred = data[0].values
label = data["label"].values
res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
print(pd.DataFrame(res,index=['Test']))
save_path = os.path.join(f'out_ml/{instruments}_xgb_{year}', 'ret_s.npy')
np.save(save_path, ret_s)
# Out:
#             ic    ic_std      icir       ric   ric_std     ricir       ret  \
# Test  0.034912  0.128982  0.270678  0.061421  0.131839  0.465875  0.843521
#
#       ret_std     retir  ret_sharpe   ret_mdd
# Test   0.0364  0.101936    1.618177  0.554259

# %% [markdown]
# # Show MLP Result

# %%
import pandas as pd
instruments = 'csi300'

result_all = []
for seed in range(5):
    result = []
    for year in range(2021,2024):
        result.append(pd.read_pickle(f'out_ml/{instruments}_mlp_{year}/pred_{seed}.pkl'))
    df = pd.concat(result,axis=0)
    data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
    pred = data[0].values
    label = data["label"].values
    res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
    res = pd.DataFrame(res,index=['Test'])
    # print(pd.DataFrame(res,index=['Test']))
    save_path = os.path.join(f'out_ml/{instruments}_mlp_{year}', 'ret_s.npy')
    np.save(save_path, ret_s)
    result_all.append(res)
#     df.columns = ['pred','label']
#     df=df[['pred','label']]



#     def get_final_metrics(df):
#         ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#         ic_s = ic_raw.mean(axis=0)
#         ic_s_std = ic_raw.std(axis=0)
#         icir_s = ic_s/ic_s_std

#         ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#         ric_s = ric_raw.mean(axis=0)
#         ric_s_std = ric_raw.std(axis=0)
#         ricir_s = ric_s/ric_s_std
#         return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}
#     tmp = get_final_metrics(df)
#     result_all.append(tmp)
# print('MLP Result:\n')
result_all = pd.concat(result_all)
print(result_all.mean())
# Out:
# ic            0.026453
# ic_std        0.131114
# icir          0.203308
# ric           0.038445
# ric_std       0.128045
# ricir         0.300524
# ret           0.117152
# ret_std       0.004836
# retir         0.109590
# ret_sharpe    1.739688
# ret_mdd       0.272837
# dtype: float64

# %%
import pandas as pd
instruments = 'csi500'

result_all = []
for seed in range(5):
    result = []
    for year in range(2021,2024):
        result.append(pd.read_pickle(f'out_ml/{instruments}_mlp_{year}/pred_{seed}.pkl'))
    df = pd.concat(result,axis=0)#.groupby('datetime').corr('spearman')['label'].unstack().mean()
    data = df.pivot_table(index="datetime", columns="instrument", values=[0,"label"])
    pred = data[0].values
    label = data["label"].values
    res, ret_s = get_tensor_metrics(torch.tensor(pred), torch.tensor(label))
    res = pd.DataFrame(res,index=['Test'])
    save_path = os.path.join(f'out_ml/{instruments}_mlp_{year}', 'ret_s.npy')
    np.save(save_path, ret_s)
    result_all.append(res)

#     df.columns = ['pred','label']
#     df=df[['pred','label']]



#     def get_final_metrics(df):
#         ic_raw = df.groupby('datetime').corr()['label'].unstack().iloc[:,:-1]
#         ic_s = ic_raw.mean(axis=0)
#         ic_s_std = ic_raw.std(axis=0)
#         icir_s = ic_s/ic_s_std

#         ric_raw = df.groupby('datetime').corr('spearman')['label'].unstack().iloc[:,:-1]
#         ric_s = ric_raw.mean(axis=0)
#         ric_s_std = ric_raw.std(axis=0)
#         ricir_s = ric_s/ric_s_std
#         return {'IC':ic_s.mean(),'ICIR':icir_s.mean(),'RankIC':ric_s.mean(),'RankICIR':ricir_s.mean()}
#     tmp = get_final_metrics(df)
#     result_all.append(tmp)
# print('MLP Result:\n')
result_all = pd.concat(result_all)
print(result_all.mean())
# Out:
# ic            0.027865
# ic_std        0.095836
# icir          0.290727
# ric           0.041102
# ric_std       0.099323
# ricir         0.413515
# ret           0.211945
# ret_std       0.005011
# retir         0.186450
# ret_sharpe    2.959795
# ret_mdd       0.123707
# dtype: float64
